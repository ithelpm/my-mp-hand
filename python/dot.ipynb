# %%
import graphviz
dot = graphviz.Digraph(comment='AI手勢控制電燈光源')

# %%
dot.node('A', '相機捕捉手勢', fontname='UTF-8')
dot.node('B', '圖像前處理', fontname='UTF-8')
dot.node('C', '手勢辨識模型', fontname='UTF-8')
dot.node('D', '指令解析', fontname='UTF-8')
dot.node('E', '電燈光源控制', fontname='UTF-8')
dot.node('F', '反饋機制', fontname='UTF-8')
dot.node('G', '例外處理', fontname='UTF-8')
dot.node('H', '終止程序', fontname='UTF-8')

dot.edges(['AB', 'BC', 'CD', 'DE', 'EF', 'DG', 'GH'])

# %%
dot
# Out:
# (dot.exe:3264): Pango-WARNING **: couldn't load font "UTF-8 Not-Rotated 14", falling back to "Sans Not-Rotated 14", expect ugly output.
